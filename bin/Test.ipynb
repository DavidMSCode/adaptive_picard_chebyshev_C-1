# %%
import APC as APyC
import plotly.graph_objects as go
import numpy as np

# %%
def spheres(size,pos=[0,0,0],res=100):
    #angular coordinates
    theta = np.linspace(0,2*np.pi,res)
    phi = np.linspace(0,np.pi,res)
    #cartesian coordinates
    x0 = pos[0]+size*np.outer(np.cos(theta),np.sin(phi))
    y0 = pos[1]+size*np.outer(np.sin(theta),np.sin(phi))
    z0 = pos[2]+size*np.outer(np.ones(res),np.cos(phi))

    return x0,y0,z0

def plot_sphere(size,color='blue',opacity=0.3,pos=[0,0,0],res=100):
    x,y,z = spheres(size,pos,res)
    trace = go.Surface(x=x,y=y,z=z,colorscale=[[0,color],[1,color]],opacity=opacity,showscale=False)
    return trace

# %%
#LEO
r0 = [6500, 0.0, 0.0];                                    # Initial Position (km)
v0 = (0, 7.90882662, 0.0);                              # Initial Velocity (km/s)
t0 = 0.0;                                                 # Initial Times (s)
tf = 1.2*5059.648765;                                     # Final Time (s)
# #MEO
# r0 = [9000.0, 0.0, 0.0];                                    # Initial Position (km)
# v0 = [0.0, 6.7419845635570, 1.806509319188210];             # Initial Velocity (km/s)
# t0 = 0.0;                                                   # Initial Times (s)
# tf = 10*9.952014050491189e+03;                              # Final Time (s)

#run APC code and save to textfile
APyC.Propagate(r0,v0,t0,tf)

#read data from textfile
output = np.loadtxt('output.txt')
ts = output[:,0]
Xs = output[:,1:4]
Vs = output[:,4:7]
H = output[:,7]


"""Plot topdown view"""
trace2d = go.Scatter(x=Xs[:,0],y=Xs[:,1],mode = 'lines')
fig2d = go.Figure(data=[trace2d])
fig2d.update_layout(
    #scene_aspectmode='data',
    showlegend=False,
    width = 800,
    height = 800,
    margin=dict(l=20, r=20, t=20, b=20))
fig2d.show()


# trace = go.Scatter3d(x=Xs[:,0],y=Xs[:,1],z=Xs[:,2],mode='lines',line=dict(color='red'))
# trace2 = plot_sphere(6378,res=30)
# fig = go.Figure(data=[trace, trace2])
# fig.update_coloraxes(showscale=False)
# fig.update_layout(
#     scene_aspectmode='data',
#     showlegend=False,
#     width = 800,
#     height = 800,
#     margin=dict(l=20, r=20, t=20, b=20)
# )
# fig.show()
# Out:
# NSt3__16vectorIdNS_9allocatorIdEEEEfinished loading matricesElapsed time: 0.051870 s	Func Evals: 1420	Hmax 6.5111789167612231E-15

# %%
#read data from test output
output = np.loadtxt('output_test.txt')
ts = output[:,0]
Xs = output[:,1:4]
Vs = output[:,4:7]
H = output[:,7]


"""Plot topdown view"""
trace2d = go.Scatter(x=Xs[:,0],y=Xs[:,1],mode = 'lines')
fig2d = go.Figure(data=[trace2d])
fig2d.update_layout(
    #scene_aspectmode='data',
    showlegend=False,
    width = 800,
    height = 800,
    margin=dict(l=20, r=20, t=20, b=20))
fig2d.show()


# trace = go.Scatter3d(x=Xs[:,0],y=Xs[:,1],z=Xs[:,2],mode='lines',line=dict(color='red'))
# trace2 = plot_sphere(6378,res=30)
# fig = go.Figure(data=[trace, trace2])
# fig.update_coloraxes(showscale=False)
# fig.update_layout(
#     scene_aspectmode='data',
#     showlegend=False,
#     width = 800,
#     height = 800,
#     margin=dict(l=20, r=20, t=20, b=20)
# )
# fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9d7bd06351cf> in <module>
#       1 #read data from test output
# ----> 2 output = np.loadtxt('output_test.txt')
#       3 ts = output[:,0]
#       4 Xs = output[:,1:4]
#       5 Vs = output[:,4:7]
#
# NameError: name 'np' is not defined

# %%
print(Vs)
# Out:
# [[ 1.00000000e+00  7.90882662e+00 -8.19180694e-24]
#  [ 7.17892621e-01  7.90370024e+00 -1.19197804e-07]
#  [ 4.38747021e-01  7.88851707e+00  3.11236319e-07]
#  [ 1.62882313e-01  7.86357345e+00  1.43651344e-06]
#  [-1.09405088e-01  7.82916995e+00  3.05159216e-06]
#  [-3.77841209e-01  7.78561062e+00  4.86254784e-06]
#  [-6.42173941e-01  7.73320087e+00  6.48639362e-06]
#  [-9.02171409e-01  7.67224622e+00  7.68692210e-06]
#  [-1.15762109e+00  7.60305183e+00  8.55853400e-06]
#  [-1.40832957e+00  7.52592158e+00  9.27936329e-06]
#  [-1.65412178e+00  7.44115668e+00  9.91251372e-06]
#  [-1.89483975e+00  7.34905457e+00  1.04860583e-05]
#  [-2.13034131e+00  7.24990824e+00  1.10453031e-05]
#  [-2.36049900e+00  7.14400584e+00  1.15953834e-05]
#  [-2.58519916e+00  7.03163025e+00  1.20892228e-05]
#  [-2.80434097e+00  6.91305876e+00  1.24882805e-05]
#  [-3.01783552e+00  6.78856292e+00  1.28101583e-05]
#  [-3.22560518e+00  6.65840838e+00  1.31122108e-05]
#  [-3.42758306e+00  6.52285457e+00  1.34400461e-05]
#  [-3.62371213e+00  6.38215434e+00  1.38023865e-05]
#  [-3.81394437e+00  6.23655383e+00  1.41871888e-05]
#  [-3.99823997e+00  6.08629257e+00  1.45814079e-05]
#  [-4.17656679e+00  5.93160341e+00  1.49694784e-05]
#  [-4.34889970e+00  5.77271255e+00  1.53233914e-05]
#  [-4.51522001e+00  5.60983948e+00  1.56016435e-05]
#  [-4.67551475e+00  5.44319707e+00  1.57571804e-05]
#  [-4.82977619e+00  5.27299171e+00  1.57473622e-05]
#  [-4.97800127e+00  5.09942339e+00  1.55421328e-05]
#  [-5.12019108e+00  4.92268591e+00  1.51287521e-05]
#  [-5.25635048e+00  4.74296701e+00  1.45119296e-05]
#  [-5.38648762e+00  4.56044859e+00  1.37097954e-05]
#  [-5.51061356e+00  4.37530689e+00  1.27478019e-05]
#  [-5.62874194e+00  4.18771269e+00  1.16528164e-05]
#  [-5.74088864e+00  3.99783149e+00  1.04488207e-05]
#  [-5.84707150e+00  3.80582375e+00  9.15475914e-06]
#  [-5.94730999e+00  3.61184503e+00  7.78439142e-06]
#  [-6.04162498e+00  3.41604624e+00  6.34752713e-06]
#  [-6.13003845e+00  3.21857386e+00  4.85186429e-06]
#  [-6.21257331e+00  3.01957008e+00  3.30483100e-06]
#  [-6.28925313e+00  2.81917309e+00  1.71506149e-06]
#  [-6.36010199e+00  2.61751729e+00  9.32555594e-08]
#  [-6.42514429e+00  2.41473347e+00 -1.54773519e-06]
#  [-6.48440458e+00  2.21094903e+00 -3.19356104e-06]
#  [-6.53790742e+00  2.00628823e+00 -4.82950280e-06]
#  [-6.58567725e+00  1.80087238e+00 -6.44167207e-06]
#  [-6.62773828e+00  1.59482003e+00 -8.01789218e-06]
#  [-6.66411435e+00  1.38824724e+00 -9.54802167e-06]
#  [-6.69482890e+00  1.18126773e+00 -1.10237166e-05]
#  [-6.71990480e+00  9.73993113e-01 -1.24378383e-05]
#  [-6.73936438e+00  7.66533094e-01 -1.37837951e-05]
#  [-6.75322928e+00  5.58995680e-01 -1.50550616e-05]
#  [-6.76152044e+00  3.51487375e-01 -1.62450347e-05]
#  [-6.76425806e+00  1.44113386e-01 -1.73472921e-05]
#  [-6.76146156e+00 -6.30221768e-02 -1.83561970e-05]
#  [-6.75314956e+00 -2.69816105e-01 -1.92676436e-05]
#  [-6.73933988e+00 -4.76165894e-01 -2.00796685e-05]
#  [-6.72004954e+00 -6.81969555e-01 -2.07926876e-05]
#  [-6.69529474e+00 -8.87125425e-01 -2.14092603e-05]
#  [-6.66509090e+00 -1.09153198e+00 -2.19334536e-05]
#  [-6.62945270e+00 -1.29508766e+00 -2.23700589e-05]
#  [-6.58839405e+00 -1.49769066e+00 -2.27240024e-05]
#  [-6.54192819e+00 -1.69923880e+00 -2.30001744e-05]
#  [-6.49006768e+00 -1.89962929e+00 -2.32036034e-05]
#  [-6.43282448e+00 -2.09875857e+00 -2.33396339e-05]
#  [-6.37021001e+00 -2.29652213e+00 -2.34137496e-05]
#  [-6.30223523e+00 -2.49281433e+00 -2.34309288e-05]
#  [-6.22891069e+00 -2.68752824e+00 -2.33947270e-05]
#  [-6.15024662e+00 -2.88055542e+00 -2.33064545e-05]
#  [-6.06625307e+00 -3.07178579e+00 -2.31647846e-05]
#  [-5.97693995e+00 -3.26110742e+00 -2.29659290e-05]
#  [-5.88231719e+00 -3.44840639e+00 -2.27042833e-05]
#  [-5.78239484e+00 -3.63356657e+00 -2.23733254e-05]
#  [-5.67718321e+00 -3.81646948e+00 -2.19665905e-05]
#  [-5.56669306e+00 -3.99699409e+00 -2.14786566e-05]
#  [-5.45093568e+00 -4.17501666e+00 -2.09060945e-05]
#  [-5.32992315e+00 -4.35041058e+00 -2.02482562e-05]
#  [-5.20366850e+00 -4.52304618e+00 -1.95076865e-05]
#  [-5.07218590e+00 -4.69279058e+00 -1.86899910e-05]
#  [-4.93549087e+00 -4.85950754e+00 -1.78033116e-05]
#  [-4.79360057e+00 -5.02305730e+00 -1.68579938e-05]
#  [-4.64653397e+00 -5.18329643e+00 -1.58669458e-05]
#  [-4.49431218e+00 -5.34007770e+00 -1.48462302e-05]
#  [-4.33695865e+00 -5.49324993e+00 -1.38147271e-05]
#  [-4.17449951e+00 -5.64265786e+00 -1.27929086e-05]
#  [-4.00696389e+00 -5.78814196e+00 -1.18029118e-05]
#  [-3.83438426e+00 -5.92953838e+00 -1.08714781e-05]
#  [-3.65679680e+00 -6.06667877e+00 -1.00331028e-05]
#  [-3.47424181e+00 -6.19939024e+00 -9.32831543e-06]
#  [-3.28676412e+00 -6.32749528e+00 -8.79606646e-06]
#  [-3.09441353e+00 -6.45081172e+00 -8.46535595e-06]
#  [-2.89724519e+00 -6.56915267e+00 -8.35169413e-06]
#  [-2.69532015e+00 -6.68232651e+00 -8.45928596e-06]
#  [-2.48870586e+00 -6.79013688e+00 -8.78625791e-06]
#  [-2.27747668e+00 -6.89238270e+00 -9.32923244e-06]
#  [-2.06171444e+00 -6.98885828e+00 -1.00844450e-05]
#  [-1.84150910e+00 -7.07935335e+00 -1.10463585e-05]
#  [-1.61695925e+00 -7.16365327e+00 -1.22048270e-05]
#  [-1.38817283e+00 -7.24153918e+00 -1.35353187e-05]
#  [-1.15526774e+00 -7.31278827e+00 -1.49856100e-05]
#  [-9.18372405e-01 -7.37717401e+00 -1.64872052e-05]
#  [-6.77626513e-01 -7.43446646e+00 -1.79989950e-05]
#  [-4.33181771e-01 -7.48443246e+00 -1.95266759e-05]
#  [-1.85202800e-01 -7.52683623e+00 -2.10839094e-05]
#  [ 6.61321825e-02 -7.56144001e+00 -2.26616210e-05]
#  [ 3.20630777e-01 -7.58800468e+00 -2.42473092e-05]
#  [ 5.78085698e-01 -7.60629031e+00 -2.58361767e-05]
#  [ 8.38274005e-01 -7.61605681e+00 -2.74240672e-05]
#  [ 1.10095629e+00 -7.61706478e+00 -2.90104128e-05]
#  [ 1.36587576e+00 -7.60907642e+00 -3.05674748e-05]
#  [ 1.63275777e+00 -7.59185688e+00 -3.20195402e-05]
#  [ 1.90130938e+00 -7.56517504e+00 -3.33045207e-05]
#  [ 2.17121835e+00 -7.52880469e+00 -3.44182516e-05]
#  [ 2.44215253e+00 -7.48252627e+00 -3.54158169e-05]
#  [ 2.71375986e+00 -7.42612814e+00 -3.63090084e-05]
#  [ 2.98566767e+00 -7.35940795e+00 -3.68782572e-05]
#  [ 3.25748242e+00 -7.28217450e+00 -3.69479985e-05]
#  [ 3.52878932e+00 -7.19424910e+00 -3.67526979e-05]
#  [ 3.79915153e+00 -7.09546812e+00 -3.65567201e-05]
#  [ 4.06811165e+00 -6.98568574e+00 -3.62968097e-05]
#  [ 4.33519296e+00 -6.86477411e+00 -3.56693758e-05]
#  [ 4.59989722e+00 -6.73262538e+00 -3.47706543e-05]
#  [ 4.86170554e+00 -6.58915658e+00 -3.35654052e-05]
#  [ 5.12008241e+00 -6.43430919e+00 -3.02945958e-05]
#  [ 5.37447226e+00 -6.26805124e+00 -2.53558091e-05]
#  [ 5.62430493e+00 -6.09038451e+00 -2.12871918e-05]
#  [ 5.86899554e+00 -5.90133527e+00 -1.69961406e-05]
#  [ 6.10793454e+00 -5.70097224e+00 -1.63101351e-05]
#  [ 6.34052228e+00 -5.48940544e+00 -2.27148042e-05]
#  [ 6.56613649e+00 -5.26676158e+00 -1.93559417e-05]
#  [ 6.78414013e+00 -5.03324436e+00 -4.67079855e-06]
#  [ 6.99394213e+00 -4.78906270e+00 -1.91589371e-07]
#  [ 7.19488302e+00 -4.53445716e+00  1.22954945e-05]
#  [ 7.38631589e+00 -4.26980442e+00  1.61556222e-05]
#  [ 7.56766896e+00 -3.99545357e+00 -3.68402273e-06]
#  [ 7.73832170e+00 -3.71177188e+00 -3.27852175e-06]
#  [ 7.89769352e+00 -3.41924424e+00 -3.15408404e-05]
#  [ 8.04525591e+00 -3.11829984e+00 -2.58411463e-05]
#  [ 8.18036379e+00 -2.80952106e+00 -4.65975021e-05]
#  [ 8.30263380e+00 -2.49352184e+00 -1.21458414e-04]
#  [ 8.41146138e+00 -2.17078000e+00 -6.82399904e-05]
#  [ 8.50637676e+00 -1.84228794e+00 -5.80766156e-05]
#  [ 8.58715460e+00 -1.50851861e+00 -3.52723335e-06]
#  [ 8.65323113e+00 -1.17023760e+00  2.02110404e-05]
#  [ 8.70442941e+00 -8.28291046e-01  5.79829972e-05]
#  [ 8.74038752e+00 -4.83503621e-01  1.81461505e-04]
#  [ 8.76107250e+00 -1.36608087e-01  1.78006873e-04]
#  [ 8.76615630e+00  2.11728708e-01  4.26912571e-05]
#  [ 8.75554202e+00  5.60370458e-01 -4.87311602e-05]
#  [ 8.72928716e+00  9.08399369e-01  9.12842753e-05]
#  [ 8.68735615e+00  1.25492155e+00  2.14353955e-04]
#  [ 8.63011943e+00  1.59910765e+00  4.78868838e-04]
#  [ 8.55738767e+00  1.94093175e+00  3.08973825e-04]
#  [ 8.46914467e+00  2.27829691e+00  2.06799439e-04]
#  [ 8.36659213e+00  2.61127008e+00  5.10123822e-05]
#  [ 8.24868708e+00  2.93870658e+00 -2.05454709e-04]
#  [ 8.11725987e+00  3.25944540e+00 -3.97645368e-04]
#  [ 7.97151302e+00  3.57358497e+00 -6.74722178e-04]
#  [ 7.81296153e+00  3.87907944e+00 -5.07669252e-04]
#  [ 7.64168460e+00  4.17779925e+00 -7.11963643e-04]
#  [ 7.45692198e+00  4.46699341e+00 -4.74645752e-04]
#  [ 7.26152915e+00  4.74577138e+00 -3.12738441e-04]
#  [ 7.05506358e+00  5.01517544e+00 -5.24863060e-04]
#  [ 6.83773589e+00  5.27398076e+00 -3.12037484e-04]
#  [ 6.61083084e+00  5.52145282e+00 -2.53542013e-04]
#  [ 6.37500543e+00  5.75773655e+00 -2.76807427e-04]
#  [ 6.13053508e+00  5.98241717e+00 -3.59135313e-04]
#  [ 5.87847857e+00  6.19482760e+00 -4.27509180e-04]
#  [ 5.61959743e+00  6.39505146e+00 -3.02303418e-04]
#  [ 5.35437748e+00  6.58293743e+00 -2.18125394e-04]]
